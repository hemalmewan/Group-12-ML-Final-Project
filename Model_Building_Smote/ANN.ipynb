# %%
import pandas as pd
import numpy as np
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder,OneHotEncoder,StandardScaler
from sklearn.metrics import accuracy_score,precision_score,recall_score,classification_report
import tensorflow as tf
from scikeras.wrappers import KerasClassifier

# %%
train_data=pd.read_csv("../dataset/train_data.csv")
test_data=pd.read_csv("../dataset/test_data.csv")

# %%
print(f"Shape of the Training data:{train_data.shape}")
print(f"Shape of the Testing data:{test_data.shape}")
# Out:
# Shape of the Training data:(1550, 13)
# Shape of the Testing data:(388, 13)

# %%
train_data=train_data=train_data.drop(["Unnamed: 0"],axis=1)
test_data=test_data.drop(["Unnamed: 0"],axis=1)

# %%
##split train data into the X_train and Y_train
X_train=train_data.drop(["delivery_status"],axis=1)
Y_train=train_data["delivery_status"]

##split test data into the X_test and Y_test
X_test=test_data.drop(["delivery_status"],axis=1)
Y_test=test_data["delivery_status"]

##Adjust the datatype of  assembly_service_requested column
X_test["assembly_service_requested"]=X_test["assembly_service_requested"].astype("object")
##Adjust the datatype of  assembly_service_requested column
X_train["assembly_service_requested"]=X_train["assembly_service_requested"].astype("object")

# %%
# ### Numbercal columns 
numerical_features=X_train.select_dtypes(include="number").columns.to_list()
categorical_features=X_train.select_dtypes(include="object").columns.to_list()

###Nominal variables
categorical_features.remove("brand")
##Ordinal variables
ordinal_features=["brand"]

# %%
##mapping y variable with the numeric values
y_map={"Failed Delivery":0,"On Going":1,"Delivered":2}
Y_train=Y_train.map(y_map)
Y_test=Y_test.map(y_map)

# %%
### Define pipelines
nominal_pipeline=Pipeline(steps=[
    ("One-Hot-Encoder",OneHotEncoder(sparse_output=False,handle_unknown="ignore"))
])
numerical_pipeline=Pipeline(steps=[
    ("Standard Scaler",StandardScaler())
])

ordinal_pipeline=Pipeline(steps=[
    ("Ordinal-Encoder",OrdinalEncoder())
])

transfomer=ColumnTransformer(transformers=[
    ("Numerical Pipeline",numerical_pipeline,numerical_features),
    ("Nominal Pipeline",nominal_pipeline,categorical_features),
    ("Ordinal Pipeline",ordinal_pipeline,ordinal_features),
  
])

final_pipeline=Pipeline(steps=[
    ("Transfomer",transfomer),
    ("Resampling SMOTE",SMOTE(random_state=42)),
])

# %%
X_train_resample,Y_train_resample= final_pipeline.fit_resample(X_train,Y_train)

# Get the ColumnTransformer from the pipeline
preprocessor = final_pipeline.named_steps["Transfomer"]

# Get feature names from the ColumnTransformer
feature_names = preprocessor.get_feature_names_out()
X_train_resample=pd.DataFrame(X_train_resample,columns=feature_names)

# %%
# Transform test set using the preprocessor only
X_test_preprocessed = final_pipeline.named_steps["Transfomer"].transform(X_test)

feature_names = final_pipeline.named_steps["Transfomer"].get_feature_names_out()
X_test_preprocessed = pd.DataFrame(X_test_preprocessed, columns=feature_names)

# %%
##implementing ANN using tensorflow
model=tf.keras.Sequential([
    tf.keras.layers.Input(shape=(X_train_resample.shape[1],)), ##Input Layer
    tf.keras.layers.Dense(10,activation="relu"), ## First Hidden Layer
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(6,activation="relu"), ##Second Hidden Layer
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(8,activation="relu"), ##Third Hidden Layer
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(3,activation="softmax") ##Outpur Layer
])

model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])
model.fit(X_train_resample,Y_train_resample,validation_data=(X_test_preprocessed,Y_test),epochs=200,batch_size=20,verbose=1)
# Out:
# Epoch 1/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.3181 - loss: 1.4969 - val_accuracy: 0.2191 - val_loss: 1.1707
# Epoch 2/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3342 - loss: 1.3448 - val_accuracy: 0.2320 - val_loss: 1.1652
# Epoch 3/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3372 - loss: 1.2517 - val_accuracy: 0.2216 - val_loss: 1.1536
# Epoch 4/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3520 - loss: 1.1872 - val_accuracy: 0.2242 - val_loss: 1.1420
# Epoch 5/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3303 - loss: 1.1799 - val_accuracy: 0.2191 - val_loss: 1.1296
# Epoch 6/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3446 - loss: 1.1409 - val_accuracy: 0.2320 - val_loss: 1.1234
# Epoch 7/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3342 - loss: 1.1389 - val_accuracy: 0.2448 - val_loss: 1.1160
# Epoch 8/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3438 - loss: 1.1139 - val_accuracy: 0.2371 - val_loss: 1.1123
# Epoch 9/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3694 - loss: 1.1060 - val_accuracy: 0.2397 - val_loss: 1.1139
# Epoch 10/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3472 - loss: 1.1117 - val_accuracy: 0.2320 - val_loss: 1.1128
# Epoch 11/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3342 - loss: 1.1130 - val_accuracy: 0.2242 - val_loss: 1.1110
# Epoch 12/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3503 - loss: 1.1024 - val_accuracy: 0.2191 - val_loss: 1.1119
# Epoch 13/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3416 - loss: 1.1056 - val_accuracy: 0.2216 - val_loss: 1.1081
# Epoch 14/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3385 - loss: 1.1040 - val_accuracy: 0.2423 - val_loss: 1.1042
# Epoch 15/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3472 - loss: 1.0999 - val_accuracy: 0.2371 - val_loss: 1.1041
# Epoch 16/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3259 - loss: 1.1020 - val_accuracy: 0.2423 - val_loss: 1.1042
# Epoch 17/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3420 - loss: 1.1025 - val_accuracy: 0.2423 - val_loss: 1.1035
# Epoch 18/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3272 - loss: 1.1004 - val_accuracy: 0.3222 - val_loss: 1.1016
# Epoch 19/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3146 - loss: 1.1010 - val_accuracy: 0.3222 - val_loss: 1.1001
# Epoch 20/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3233 - loss: 1.0990 - val_accuracy: 0.3479 - val_loss: 1.1001
# Epoch 21/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3368 - loss: 1.0991 - val_accuracy: 0.3196 - val_loss: 1.1002
# Epoch 22/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3272 - loss: 1.1004 - val_accuracy: 0.2629 - val_loss: 1.1003
# Epoch 23/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3368 - loss: 1.0988 - val_accuracy: 0.2423 - val_loss: 1.0997
# Epoch 24/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3290 - loss: 1.0993 - val_accuracy: 0.2242 - val_loss: 1.1001
# Epoch 25/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3390 - loss: 1.0987 - val_accuracy: 0.3067 - val_loss: 1.0985
# Epoch 26/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3364 - loss: 1.0990 - val_accuracy: 0.3814 - val_loss: 1.0981
# Epoch 27/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3372 - loss: 1.0989 - val_accuracy: 0.2603 - val_loss: 1.0991
# Epoch 28/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3381 - loss: 1.0982 - val_accuracy: 0.2861 - val_loss: 1.0983
# Epoch 29/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3307 - loss: 1.0999 - val_accuracy: 0.3376 - val_loss: 1.0978
# Epoch 30/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3207 - loss: 1.0997 - val_accuracy: 0.3093 - val_loss: 1.0986
# Epoch 31/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3246 - loss: 1.0994 - val_accuracy: 0.3866 - val_loss: 1.0973
# Epoch 32/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3368 - loss: 1.0986 - val_accuracy: 0.3067 - val_loss: 1.0988
# Epoch 33/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3446 - loss: 1.0986 - val_accuracy: 0.3995 - val_loss: 1.0966
# Epoch 34/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3299 - loss: 1.0996 - val_accuracy: 0.3299 - val_loss: 1.0987
# Epoch 35/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3407 - loss: 1.0991 - val_accuracy: 0.2577 - val_loss: 1.0993
# Epoch 36/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3303 - loss: 1.0988 - val_accuracy: 0.3273 - val_loss: 1.0973
# Epoch 37/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3412 - loss: 1.0993 - val_accuracy: 0.3737 - val_loss: 1.0964
# Epoch 38/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3455 - loss: 1.0988 - val_accuracy: 0.4794 - val_loss: 1.0949
# Epoch 39/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3294 - loss: 1.0989 - val_accuracy: 0.4716 - val_loss: 1.0953
# Epoch 40/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3433 - loss: 1.0997 - val_accuracy: 0.2655 - val_loss: 1.0990
# Epoch 41/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3490 - loss: 1.0984 - val_accuracy: 0.2809 - val_loss: 1.0989
# Epoch 42/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3312 - loss: 1.0989 - val_accuracy: 0.2680 - val_loss: 1.0993
# Epoch 43/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3372 - loss: 1.0997 - val_accuracy: 0.3273 - val_loss: 1.0977
# Epoch 44/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3351 - loss: 1.0992 - val_accuracy: 0.3943 - val_loss: 1.0972
# Epoch 45/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3277 - loss: 1.0994 - val_accuracy: 0.4536 - val_loss: 1.0969
# Epoch 46/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3242 - loss: 1.0996 - val_accuracy: 0.3557 - val_loss: 1.0981
# Epoch 47/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3342 - loss: 1.0987 - val_accuracy: 0.4562 - val_loss: 1.0975
# Epoch 48/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3146 - loss: 1.0998 - val_accuracy: 0.3608 - val_loss: 1.0987
# Epoch 49/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3233 - loss: 1.0986 - val_accuracy: 0.4278 - val_loss: 1.0978
# Epoch 50/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3381 - loss: 1.0986 - val_accuracy: 0.3943 - val_loss: 1.0990
# Epoch 51/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3264 - loss: 1.0996 - val_accuracy: 0.4433 - val_loss: 1.0966
# Epoch 52/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3381 - loss: 1.0986 - val_accuracy: 0.4510 - val_loss: 1.0966
# Epoch 53/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3229 - loss: 1.0993 - val_accuracy: 0.4536 - val_loss: 1.0980
# Epoch 54/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3220 - loss: 1.0996 - val_accuracy: 0.3660 - val_loss: 1.0972
# Epoch 55/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3329 - loss: 1.0992 - val_accuracy: 0.3041 - val_loss: 1.0973
# Epoch 56/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3194 - loss: 1.0995 - val_accuracy: 0.3041 - val_loss: 1.0998
# Epoch 57/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3212 - loss: 1.0991 - val_accuracy: 0.3454 - val_loss: 1.0985
# Epoch 58/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3472 - loss: 1.0984 - val_accuracy: 0.3814 - val_loss: 1.0977
# Epoch 59/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3268 - loss: 1.0987 - val_accuracy: 0.3686 - val_loss: 1.0985
# Epoch 60/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3299 - loss: 1.0999 - val_accuracy: 0.2861 - val_loss: 1.0990
# Epoch 61/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3277 - loss: 1.0995 - val_accuracy: 0.2113 - val_loss: 1.1009
# Epoch 62/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3307 - loss: 1.0984 - val_accuracy: 0.3866 - val_loss: 1.0981
# Epoch 63/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3073 - loss: 1.0992 - val_accuracy: 0.3660 - val_loss: 1.0984
# Epoch 64/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3203 - loss: 1.0995 - val_accuracy: 0.3634 - val_loss: 1.0986
# Epoch 65/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3355 - loss: 1.0983 - val_accuracy: 0.3479 - val_loss: 1.0982
# Epoch 66/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3359 - loss: 1.0993 - val_accuracy: 0.3660 - val_loss: 1.0976
# Epoch 67/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3381 - loss: 1.0982 - val_accuracy: 0.2809 - val_loss: 1.0986
# Epoch 68/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3246 - loss: 1.0992 - val_accuracy: 0.3247 - val_loss: 1.0976
# Epoch 69/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3320 - loss: 1.0988 - val_accuracy: 0.4175 - val_loss: 1.0951
# Epoch 70/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3472 - loss: 1.0983 - val_accuracy: 0.4536 - val_loss: 1.0942
# Epoch 71/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3425 - loss: 1.0981 - val_accuracy: 0.3943 - val_loss: 1.0966
# Epoch 72/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3412 - loss: 1.0992 - val_accuracy: 0.3840 - val_loss: 1.0957
# Epoch 73/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3538 - loss: 1.0978 - val_accuracy: 0.4304 - val_loss: 1.0939
# Epoch 74/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3346 - loss: 1.0984 - val_accuracy: 0.4072 - val_loss: 1.0947
# Epoch 75/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3394 - loss: 1.0987 - val_accuracy: 0.3660 - val_loss: 1.0966
# Epoch 76/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3307 - loss: 1.0985 - val_accuracy: 0.3454 - val_loss: 1.0967
# Epoch 77/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3355 - loss: 1.0992 - val_accuracy: 0.3015 - val_loss: 1.0985
# Epoch 78/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3425 - loss: 1.0983 - val_accuracy: 0.2706 - val_loss: 1.0998
# Epoch 79/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3438 - loss: 1.0984 - val_accuracy: 0.2912 - val_loss: 1.0992
# Epoch 80/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3394 - loss: 1.0998 - val_accuracy: 0.2990 - val_loss: 1.0992
# Epoch 81/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3307 - loss: 1.0990 - val_accuracy: 0.3222 - val_loss: 1.0985
# Epoch 82/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3359 - loss: 1.0989 - val_accuracy: 0.3144 - val_loss: 1.0981
# Epoch 83/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3346 - loss: 1.0986 - val_accuracy: 0.3995 - val_loss: 1.0968
# Epoch 84/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3385 - loss: 1.0989 - val_accuracy: 0.3918 - val_loss: 1.0970
# Epoch 85/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3329 - loss: 1.0988 - val_accuracy: 0.3093 - val_loss: 1.0988
# Epoch 86/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3542 - loss: 1.0978 - val_accuracy: 0.2835 - val_loss: 1.0993
# Epoch 87/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3498 - loss: 1.0978 - val_accuracy: 0.3325 - val_loss: 1.0978
# Epoch 88/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3251 - loss: 1.0988 - val_accuracy: 0.3402 - val_loss: 1.0976
# Epoch 89/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3455 - loss: 1.0982 - val_accuracy: 0.3995 - val_loss: 1.0967
# Epoch 90/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3329 - loss: 1.0991 - val_accuracy: 0.4201 - val_loss: 1.0945
# Epoch 91/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3381 - loss: 1.0981 - val_accuracy: 0.3505 - val_loss: 1.0960
# Epoch 92/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3238 - loss: 1.0995 - val_accuracy: 0.3789 - val_loss: 1.0961
# Epoch 93/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3642 - loss: 1.0985 - val_accuracy: 0.4175 - val_loss: 1.0955
# Epoch 94/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3481 - loss: 1.0970 - val_accuracy: 0.4459 - val_loss: 1.0934
# Epoch 95/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3472 - loss: 1.0965 - val_accuracy: 0.4381 - val_loss: 1.0932
# Epoch 96/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3342 - loss: 1.0996 - val_accuracy: 0.3969 - val_loss: 1.0956
# Epoch 97/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3594 - loss: 1.0964 - val_accuracy: 0.3660 - val_loss: 1.0975
# Epoch 98/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3377 - loss: 1.0976 - val_accuracy: 0.3454 - val_loss: 1.0977
# Epoch 99/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3272 - loss: 1.0989 - val_accuracy: 0.2887 - val_loss: 1.0982
# Epoch 100/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3425 - loss: 1.0990 - val_accuracy: 0.2964 - val_loss: 1.0988
# Epoch 101/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3525 - loss: 1.0968 - val_accuracy: 0.2062 - val_loss: 1.1003
# Epoch 102/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3520 - loss: 1.0964 - val_accuracy: 0.2036 - val_loss: 1.1016
# Epoch 103/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3381 - loss: 1.0968 - val_accuracy: 0.2165 - val_loss: 1.1004
# Epoch 104/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3407 - loss: 1.0994 - val_accuracy: 0.1907 - val_loss: 1.1021
# Epoch 105/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3538 - loss: 1.0965 - val_accuracy: 0.2887 - val_loss: 1.0995
# Epoch 106/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3620 - loss: 1.0958 - val_accuracy: 0.3144 - val_loss: 1.0991
# Epoch 107/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3416 - loss: 1.0998 - val_accuracy: 0.3015 - val_loss: 1.0996
# Epoch 108/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3333 - loss: 1.0980 - val_accuracy: 0.3557 - val_loss: 1.0970
# Epoch 109/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3525 - loss: 1.0970 - val_accuracy: 0.3196 - val_loss: 1.0987
# Epoch 110/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3442 - loss: 1.0981 - val_accuracy: 0.3351 - val_loss: 1.0993
# Epoch 111/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3464 - loss: 1.0979 - val_accuracy: 0.3376 - val_loss: 1.0977
# Epoch 112/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3377 - loss: 1.0988 - val_accuracy: 0.2938 - val_loss: 1.0997
# Epoch 113/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3477 - loss: 1.0978 - val_accuracy: 0.3170 - val_loss: 1.0983
# Epoch 114/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3598 - loss: 1.0967 - val_accuracy: 0.3402 - val_loss: 1.0973
# Epoch 115/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3525 - loss: 1.0963 - val_accuracy: 0.3505 - val_loss: 1.0964
# Epoch 116/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3655 - loss: 1.0951 - val_accuracy: 0.3557 - val_loss: 1.0973
# Epoch 117/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3377 - loss: 1.0994 - val_accuracy: 0.3531 - val_loss: 1.0963
# Epoch 118/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3581 - loss: 1.0962 - val_accuracy: 0.2887 - val_loss: 1.0989
# Epoch 119/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3598 - loss: 1.0951 - val_accuracy: 0.2990 - val_loss: 1.0983
# Epoch 120/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3711 - loss: 1.0946 - val_accuracy: 0.3402 - val_loss: 1.0969
# Epoch 121/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3568 - loss: 1.0949 - val_accuracy: 0.3454 - val_loss: 1.0958
# Epoch 122/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3590 - loss: 1.0945 - val_accuracy: 0.3479 - val_loss: 1.0956
# Epoch 123/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3538 - loss: 1.0972 - val_accuracy: 0.3686 - val_loss: 1.0949
# Epoch 124/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3516 - loss: 1.0980 - val_accuracy: 0.3222 - val_loss: 1.0983
# Epoch 125/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3338 - loss: 1.0959 - val_accuracy: 0.2835 - val_loss: 1.1009
# Epoch 126/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3625 - loss: 1.0957 - val_accuracy: 0.3067 - val_loss: 1.1001
# Epoch 127/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3516 - loss: 1.0955 - val_accuracy: 0.3041 - val_loss: 1.0992
# Epoch 128/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3598 - loss: 1.0953 - val_accuracy: 0.3144 - val_loss: 1.0989
# Epoch 129/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3455 - loss: 1.0972 - val_accuracy: 0.3479 - val_loss: 1.0954
# Epoch 130/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3690 - loss: 1.0960 - val_accuracy: 0.3170 - val_loss: 1.0980
# Epoch 131/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3485 - loss: 1.0947 - val_accuracy: 0.3144 - val_loss: 1.0980
# Epoch 132/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3446 - loss: 1.0955 - val_accuracy: 0.3299 - val_loss: 1.0983
# Epoch 133/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3598 - loss: 1.0975 - val_accuracy: 0.2680 - val_loss: 1.1007
# Epoch 134/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3542 - loss: 1.0952 - val_accuracy: 0.2887 - val_loss: 1.1002
# Epoch 135/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3498 - loss: 1.0976 - val_accuracy: 0.3351 - val_loss: 1.0965
# Epoch 136/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3472 - loss: 1.0960 - val_accuracy: 0.3196 - val_loss: 1.0968
# Epoch 137/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3533 - loss: 1.0940 - val_accuracy: 0.3247 - val_loss: 1.0971
# Epoch 138/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3755 - loss: 1.0911 - val_accuracy: 0.3222 - val_loss: 1.0968
# Epoch 139/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3664 - loss: 1.0934 - val_accuracy: 0.3325 - val_loss: 1.0954
# Epoch 140/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3638 - loss: 1.0940 - val_accuracy: 0.3299 - val_loss: 1.0971
# Epoch 141/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3494 - loss: 1.0969 - val_accuracy: 0.3170 - val_loss: 1.0965
# Epoch 142/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3533 - loss: 1.0945 - val_accuracy: 0.2809 - val_loss: 1.0977
# Epoch 143/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3459 - loss: 1.0941 - val_accuracy: 0.2912 - val_loss: 1.0995
# Epoch 144/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3629 - loss: 1.0936 - val_accuracy: 0.2577 - val_loss: 1.1013
# Epoch 145/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3520 - loss: 1.0979 - val_accuracy: 0.2603 - val_loss: 1.1001
# Epoch 146/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3512 - loss: 1.0945 - val_accuracy: 0.2784 - val_loss: 1.0991
# Epoch 147/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3472 - loss: 1.0977 - val_accuracy: 0.2371 - val_loss: 1.0989
# Epoch 148/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3642 - loss: 1.0950 - val_accuracy: 0.2320 - val_loss: 1.0996
# Epoch 149/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3555 - loss: 1.0939 - val_accuracy: 0.3247 - val_loss: 1.0973
# Epoch 150/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3651 - loss: 1.0962 - val_accuracy: 0.3325 - val_loss: 1.0980
# Epoch 151/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3577 - loss: 1.0976 - val_accuracy: 0.2912 - val_loss: 1.0984
# Epoch 152/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3551 - loss: 1.0962 - val_accuracy: 0.3144 - val_loss: 1.0978
# Epoch 153/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3551 - loss: 1.0937 - val_accuracy: 0.2474 - val_loss: 1.0974
# Epoch 154/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3620 - loss: 1.0938 - val_accuracy: 0.2268 - val_loss: 1.1006
# Epoch 155/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3685 - loss: 1.0925 - val_accuracy: 0.2552 - val_loss: 1.0996
# Epoch 156/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3668 - loss: 1.0929 - val_accuracy: 0.2397 - val_loss: 1.1010
# Epoch 157/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3464 - loss: 1.0949 - val_accuracy: 0.2139 - val_loss: 1.1012
# Epoch 158/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3607 - loss: 1.0942 - val_accuracy: 0.2139 - val_loss: 1.1004
# Epoch 159/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3581 - loss: 1.0956 - val_accuracy: 0.2706 - val_loss: 1.0981
# Epoch 160/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3420 - loss: 1.0957 - val_accuracy: 0.2552 - val_loss: 1.0981
# Epoch 161/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3664 - loss: 1.0943 - val_accuracy: 0.2397 - val_loss: 1.0988
# Epoch 162/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3685 - loss: 1.0915 - val_accuracy: 0.2577 - val_loss: 1.1013
# Epoch 163/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3616 - loss: 1.0930 - val_accuracy: 0.2758 - val_loss: 1.0998
# Epoch 164/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3755 - loss: 1.0906 - val_accuracy: 0.2577 - val_loss: 1.0985
# Epoch 165/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3642 - loss: 1.0937 - val_accuracy: 0.2680 - val_loss: 1.0984
# Epoch 166/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3820 - loss: 1.0919 - val_accuracy: 0.3247 - val_loss: 1.0970
# Epoch 167/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3677 - loss: 1.0935 - val_accuracy: 0.3144 - val_loss: 1.0977
# Epoch 168/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3698 - loss: 1.0922 - val_accuracy: 0.3015 - val_loss: 1.0982
# Epoch 169/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3642 - loss: 1.0975 - val_accuracy: 0.2912 - val_loss: 1.0983
# Epoch 170/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3659 - loss: 1.0966 - val_accuracy: 0.3144 - val_loss: 1.0974
# Epoch 171/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3642 - loss: 1.0926 - val_accuracy: 0.2861 - val_loss: 1.0996
# Epoch 172/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3751 - loss: 1.0924 - val_accuracy: 0.3041 - val_loss: 1.0995
# Epoch 173/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3685 - loss: 1.0898 - val_accuracy: 0.2938 - val_loss: 1.0986
# Epoch 174/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3724 - loss: 1.0923 - val_accuracy: 0.2887 - val_loss: 1.0998
# Epoch 175/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3559 - loss: 1.0909 - val_accuracy: 0.2784 - val_loss: 1.1021
# Epoch 176/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3590 - loss: 1.0916 - val_accuracy: 0.2448 - val_loss: 1.1030
# Epoch 177/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3681 - loss: 1.0918 - val_accuracy: 0.2500 - val_loss: 1.1005
# Epoch 178/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3585 - loss: 1.0946 - val_accuracy: 0.2758 - val_loss: 1.0982
# Epoch 179/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3850 - loss: 1.0900 - val_accuracy: 0.2552 - val_loss: 1.1005
# Epoch 180/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3629 - loss: 1.0913 - val_accuracy: 0.2809 - val_loss: 1.0990
# Epoch 181/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3607 - loss: 1.0954 - val_accuracy: 0.2552 - val_loss: 1.1003
# Epoch 182/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3520 - loss: 1.0946 - val_accuracy: 0.2448 - val_loss: 1.1000
# Epoch 183/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3751 - loss: 1.0916 - val_accuracy: 0.2474 - val_loss: 1.1017
# Epoch 184/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3738 - loss: 1.0903 - val_accuracy: 0.2861 - val_loss: 1.0996
# Epoch 185/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3772 - loss: 1.0930 - val_accuracy: 0.2809 - val_loss: 1.1014
# Epoch 186/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3729 - loss: 1.0890 - val_accuracy: 0.3041 - val_loss: 1.0995
# Epoch 187/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3798 - loss: 1.0885 - val_accuracy: 0.2861 - val_loss: 1.1019
# Epoch 188/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3590 - loss: 1.0938 - val_accuracy: 0.2448 - val_loss: 1.1043
# Epoch 189/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3864 - loss: 1.0901 - val_accuracy: 0.2861 - val_loss: 1.0989
# Epoch 190/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3633 - loss: 1.0918 - val_accuracy: 0.2990 - val_loss: 1.0982
# Epoch 191/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3781 - loss: 1.0863 - val_accuracy: 0.2990 - val_loss: 1.0991
# Epoch 192/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3572 - loss: 1.0943 - val_accuracy: 0.2345 - val_loss: 1.1022
# Epoch 193/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3707 - loss: 1.0933 - val_accuracy: 0.2809 - val_loss: 1.1002
# Epoch 194/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3672 - loss: 1.0933 - val_accuracy: 0.2629 - val_loss: 1.0984
# Epoch 195/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3898 - loss: 1.0879 - val_accuracy: 0.2964 - val_loss: 1.0953
# Epoch 196/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3677 - loss: 1.0933 - val_accuracy: 0.3093 - val_loss: 1.0966
# Epoch 197/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3811 - loss: 1.0925 - val_accuracy: 0.3634 - val_loss: 1.0954
# Epoch 198/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3433 - loss: 1.0946 - val_accuracy: 0.2784 - val_loss: 1.0989
# Epoch 199/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3846 - loss: 1.0863 - val_accuracy: 0.3273 - val_loss: 1.0964
# Epoch 200/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3777 - loss: 1.0924 - val_accuracy: 0.2912 - val_loss: 1.0978

# %%
y_pred=model.predict(X_test_preprocessed)
y_pred
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# array([[0.30350518, 0.29028884, 0.406206  ],
#        [0.3210326 , 0.3083283 , 0.3706391 ],
#        [0.3496184 , 0.3665534 , 0.28382826],
#        ...,
#        [0.33335912, 0.32174334, 0.3448976 ],
#        [0.3271211 , 0.3149622 , 0.35791668],
#        [0.34359974, 0.3462984 , 0.31010184]],
#       shape=(388, 3), dtype=float32)

# %%
y_pred= np.argmax(y_pred, axis=1)
accuracy_score(y_pred,Y_test)
# Out:
# 0.2912371134020619

# %%
y_pred_train=model.predict(X_train_resample)
y_pred_train= np.argmax(y_pred_train, axis=1)
accuracy_score(y_pred_train,Y_train_resample)
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 0.41938287700999566
