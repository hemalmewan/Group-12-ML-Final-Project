# %% [markdown]
# ### **Import Required Libraries**

# %%
import pandas as pd
import numpy as np
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder,OneHotEncoder,StandardScaler
from sklearn.metrics import accuracy_score,precision_score,recall_score,classification_report,f1_score
import tensorflow as tf
from scikeras.wrappers import KerasClassifier

# %% [markdown]
# ### **Import Datasets**

# %%
train_data=pd.read_csv("../dataset/train_data.csv")
test_data=pd.read_csv("../dataset/test_data.csv")

# %%
print(f"Shape of the Training data:{train_data.shape}")
print(f"Shape of the Testing data:{test_data.shape}")
# Out:
# Shape of the Training data:(1550, 13)
# Shape of the Testing data:(388, 13)

# %% [markdown]
# ### **Drop Unecessary Variables**

# %%
train_data=train_data=train_data.drop(["Unnamed: 0"],axis=1)
test_data=test_data.drop(["Unnamed: 0"],axis=1)

# %%
##split train data into the X_train and Y_train
X_train=train_data.drop(["delivery_status"],axis=1)
Y_train=train_data["delivery_status"]

##split test data into the X_test and Y_test
X_test=test_data.drop(["delivery_status"],axis=1)
Y_test=test_data["delivery_status"]

##Adjust the datatype of  assembly_service_requested column
X_test["assembly_service_requested"]=X_test["assembly_service_requested"].astype("object")
##Adjust the datatype of  assembly_service_requested column
X_train["assembly_service_requested"]=X_train["assembly_service_requested"].astype("object")

# %% [markdown]
# ### **Model Building**

# %%
# ### Numbercal columns 
numerical_features=X_train.select_dtypes(include="number").columns.to_list()
categorical_features=X_train.select_dtypes(include="object").columns.to_list()

###Nominal variables
categorical_features.remove("brand")
##Ordinal variables
ordinal_features=["brand"]

# %%
##mapping y variable with the numeric values
y_map={"Failed Delivery":0,"On Going":1,"Delivered":2}
Y_train=Y_train.map(y_map)
Y_test=Y_test.map(y_map)

# %%
### Define pipelines
nominal_pipeline=Pipeline(steps=[
    ("One-Hot-Encoder",OneHotEncoder(sparse_output=False,handle_unknown="ignore"))
])
numerical_pipeline=Pipeline(steps=[
    ("Standard Scaler",StandardScaler())
])

ordinal_pipeline=Pipeline(steps=[
    ("Ordinal-Encoder",OrdinalEncoder())
])

transfomer=ColumnTransformer(transformers=[
    ("Numerical Pipeline",numerical_pipeline,numerical_features),
    ("Nominal Pipeline",nominal_pipeline,categorical_features),
    ("Ordinal Pipeline",ordinal_pipeline,ordinal_features),
  
])

final_pipeline=Pipeline(steps=[
    ("Transfomer",transfomer),
    ("Resampling SMOTE",SMOTE(random_state=42)),
])

# %%
X_train_resample,Y_train_resample= final_pipeline.fit_resample(X_train,Y_train)

# Get the ColumnTransformer from the pipeline
preprocessor = final_pipeline.named_steps["Transfomer"]

# Get feature names from the ColumnTransformer
feature_names = preprocessor.get_feature_names_out()
X_train_resample=pd.DataFrame(X_train_resample,columns=feature_names)

# %%
# Transform test set using the preprocessor only
X_test_preprocessed = final_pipeline.named_steps["Transfomer"].transform(X_test)

feature_names = final_pipeline.named_steps["Transfomer"].get_feature_names_out()
X_test_preprocessed = pd.DataFrame(X_test_preprocessed, columns=feature_names)

# %%
##implementing ANN using tensorflow
model=tf.keras.Sequential([
    tf.keras.layers.Input(shape=(X_train_resample.shape[1],)), ##Input Layer
    tf.keras.layers.Dense(10,activation="relu"), ## First Hidden Layer
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(6,activation="relu"), ##Second Hidden Layer
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(8,activation="relu"), ##Third Hidden Layer
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(3,activation="softmax") ##Outpur Layer
])

model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics=["accuracy"])
model.fit(X_train_resample,Y_train_resample,validation_data=(X_test_preprocessed,Y_test),epochs=200,batch_size=20,verbose=1)
# Out:
# Epoch 1/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3399 - loss: 1.4014 - val_accuracy: 0.3144 - val_loss: 1.1247
# Epoch 2/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3281 - loss: 1.2784 - val_accuracy: 0.3376 - val_loss: 1.1111
# Epoch 3/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3433 - loss: 1.2201 - val_accuracy: 0.3660 - val_loss: 1.1034
# Epoch 4/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3255 - loss: 1.1867 - val_accuracy: 0.3505 - val_loss: 1.1039
# Epoch 5/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3251 - loss: 1.1539 - val_accuracy: 0.3840 - val_loss: 1.0994
# Epoch 6/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3342 - loss: 1.1304 - val_accuracy: 0.4072 - val_loss: 1.0978
# Epoch 7/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3451 - loss: 1.1186 - val_accuracy: 0.3840 - val_loss: 1.0986
# Epoch 8/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3325 - loss: 1.1150 - val_accuracy: 0.3737 - val_loss: 1.0997
# Epoch 9/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3294 - loss: 1.1119 - val_accuracy: 0.3969 - val_loss: 1.0989
# Epoch 10/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3433 - loss: 1.1069 - val_accuracy: 0.4278 - val_loss: 1.0975
# Epoch 11/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3494 - loss: 1.0993 - val_accuracy: 0.3376 - val_loss: 1.0998
# Epoch 12/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3407 - loss: 1.1040 - val_accuracy: 0.4356 - val_loss: 1.0969
# Epoch 13/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3451 - loss: 1.1027 - val_accuracy: 0.4356 - val_loss: 1.0956
# Epoch 14/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3464 - loss: 1.1003 - val_accuracy: 0.4381 - val_loss: 1.0975
# Epoch 15/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3355 - loss: 1.1006 - val_accuracy: 0.4201 - val_loss: 1.0973
# Epoch 16/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3412 - loss: 1.1005 - val_accuracy: 0.4149 - val_loss: 1.0985
# Epoch 17/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3333 - loss: 1.1006 - val_accuracy: 0.3763 - val_loss: 1.0994
# Epoch 18/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3394 - loss: 1.1005 - val_accuracy: 0.4330 - val_loss: 1.0970
# Epoch 19/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3325 - loss: 1.1009 - val_accuracy: 0.4098 - val_loss: 1.0977
# Epoch 20/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3468 - loss: 1.0981 - val_accuracy: 0.3557 - val_loss: 1.0978
# Epoch 21/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3459 - loss: 1.0973 - val_accuracy: 0.3015 - val_loss: 1.0982
# Epoch 22/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3338 - loss: 1.1008 - val_accuracy: 0.4304 - val_loss: 1.0971
# Epoch 23/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3338 - loss: 1.0995 - val_accuracy: 0.2603 - val_loss: 1.1000
# Epoch 24/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3381 - loss: 1.0997 - val_accuracy: 0.2423 - val_loss: 1.1012
# Epoch 25/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3272 - loss: 1.0992 - val_accuracy: 0.2448 - val_loss: 1.1007
# Epoch 26/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3355 - loss: 1.0993 - val_accuracy: 0.2294 - val_loss: 1.1020
# Epoch 27/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3542 - loss: 1.0980 - val_accuracy: 0.2423 - val_loss: 1.1014
# Epoch 28/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3294 - loss: 1.0982 - val_accuracy: 0.2706 - val_loss: 1.0994
# Epoch 29/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3355 - loss: 1.0991 - val_accuracy: 0.2371 - val_loss: 1.1024
# Epoch 30/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3286 - loss: 1.0988 - val_accuracy: 0.2809 - val_loss: 1.1016
# Epoch 31/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3442 - loss: 1.0992 - val_accuracy: 0.2835 - val_loss: 1.0998
# Epoch 32/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3507 - loss: 1.0977 - val_accuracy: 0.2423 - val_loss: 1.1015
# Epoch 33/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3294 - loss: 1.1001 - val_accuracy: 0.2655 - val_loss: 1.0999
# Epoch 34/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3446 - loss: 1.0982 - val_accuracy: 0.3325 - val_loss: 1.0986
# Epoch 35/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3368 - loss: 1.0992 - val_accuracy: 0.2526 - val_loss: 1.1009
# Epoch 36/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3429 - loss: 1.0995 - val_accuracy: 0.2294 - val_loss: 1.1017
# Epoch 37/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3364 - loss: 1.0992 - val_accuracy: 0.2191 - val_loss: 1.1012
# Epoch 38/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3429 - loss: 1.0984 - val_accuracy: 0.2423 - val_loss: 1.1004
# Epoch 39/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3468 - loss: 1.0984 - val_accuracy: 0.2552 - val_loss: 1.1001
# Epoch 40/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3325 - loss: 1.0986 - val_accuracy: 0.2500 - val_loss: 1.0989
# Epoch 41/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3303 - loss: 1.0998 - val_accuracy: 0.2990 - val_loss: 1.0985
# Epoch 42/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3359 - loss: 1.0992 - val_accuracy: 0.2423 - val_loss: 1.1003
# Epoch 43/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3403 - loss: 1.0979 - val_accuracy: 0.2448 - val_loss: 1.1023
# Epoch 44/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3451 - loss: 1.0983 - val_accuracy: 0.2371 - val_loss: 1.1033
# Epoch 45/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3446 - loss: 1.0988 - val_accuracy: 0.2371 - val_loss: 1.1035
# Epoch 46/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3420 - loss: 1.0978 - val_accuracy: 0.2216 - val_loss: 1.1047
# Epoch 47/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3390 - loss: 1.0992 - val_accuracy: 0.2165 - val_loss: 1.1040
# Epoch 48/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3446 - loss: 1.0988 - val_accuracy: 0.2113 - val_loss: 1.1046
# Epoch 49/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3407 - loss: 1.0990 - val_accuracy: 0.2397 - val_loss: 1.1021
# Epoch 50/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3325 - loss: 1.0996 - val_accuracy: 0.2474 - val_loss: 1.1014
# Epoch 51/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3338 - loss: 1.0989 - val_accuracy: 0.2448 - val_loss: 1.1008
# Epoch 52/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3399 - loss: 1.0983 - val_accuracy: 0.2655 - val_loss: 1.1010
# Epoch 53/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3425 - loss: 1.0978 - val_accuracy: 0.2242 - val_loss: 1.1043
# Epoch 54/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3442 - loss: 1.0986 - val_accuracy: 0.2294 - val_loss: 1.1026
# Epoch 55/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3464 - loss: 1.0981 - val_accuracy: 0.2371 - val_loss: 1.1039
# Epoch 56/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3320 - loss: 1.0985 - val_accuracy: 0.2732 - val_loss: 1.1018
# Epoch 57/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3281 - loss: 1.0992 - val_accuracy: 0.2706 - val_loss: 1.1011
# Epoch 58/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3394 - loss: 1.0985 - val_accuracy: 0.2680 - val_loss: 1.1000
# Epoch 59/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3385 - loss: 1.0985 - val_accuracy: 0.2784 - val_loss: 1.0997
# Epoch 60/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3168 - loss: 1.0999 - val_accuracy: 0.3634 - val_loss: 1.0980
# Epoch 61/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3277 - loss: 1.0992 - val_accuracy: 0.2474 - val_loss: 1.1005
# Epoch 62/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3451 - loss: 1.0980 - val_accuracy: 0.3144 - val_loss: 1.0992
# Epoch 63/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3303 - loss: 1.0986 - val_accuracy: 0.3428 - val_loss: 1.0984
# Epoch 64/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3416 - loss: 1.0971 - val_accuracy: 0.3686 - val_loss: 1.0975
# Epoch 65/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3407 - loss: 1.0982 - val_accuracy: 0.3608 - val_loss: 1.0986
# Epoch 66/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3399 - loss: 1.0979 - val_accuracy: 0.2629 - val_loss: 1.1007
# Epoch 67/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3494 - loss: 1.0980 - val_accuracy: 0.2758 - val_loss: 1.1002
# Epoch 68/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3546 - loss: 1.0963 - val_accuracy: 0.3660 - val_loss: 1.0971
# Epoch 69/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3485 - loss: 1.0982 - val_accuracy: 0.3067 - val_loss: 1.0991
# Epoch 70/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3516 - loss: 1.0996 - val_accuracy: 0.3325 - val_loss: 1.0980
# Epoch 71/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3498 - loss: 1.0978 - val_accuracy: 0.3247 - val_loss: 1.0985
# Epoch 72/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3512 - loss: 1.0977 - val_accuracy: 0.3067 - val_loss: 1.0984
# Epoch 73/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3629 - loss: 1.0955 - val_accuracy: 0.2706 - val_loss: 1.1006
# Epoch 74/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3446 - loss: 1.0971 - val_accuracy: 0.2809 - val_loss: 1.1001
# Epoch 75/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3329 - loss: 1.0969 - val_accuracy: 0.2655 - val_loss: 1.1035
# Epoch 76/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3286 - loss: 1.0980 - val_accuracy: 0.2603 - val_loss: 1.1027
# Epoch 77/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3299 - loss: 1.0982 - val_accuracy: 0.2526 - val_loss: 1.1048
# Epoch 78/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3481 - loss: 1.0978 - val_accuracy: 0.2423 - val_loss: 1.1042
# Epoch 79/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3477 - loss: 1.0988 - val_accuracy: 0.2165 - val_loss: 1.1056
# Epoch 80/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3390 - loss: 1.0988 - val_accuracy: 0.2242 - val_loss: 1.1042
# Epoch 81/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3381 - loss: 1.0972 - val_accuracy: 0.2397 - val_loss: 1.1012
# Epoch 82/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3507 - loss: 1.0967 - val_accuracy: 0.2500 - val_loss: 1.1025
# Epoch 83/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3455 - loss: 1.0979 - val_accuracy: 0.2423 - val_loss: 1.1017
# Epoch 84/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3429 - loss: 1.0984 - val_accuracy: 0.2397 - val_loss: 1.1021
# Epoch 85/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3577 - loss: 1.0953 - val_accuracy: 0.2423 - val_loss: 1.1034
# Epoch 86/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3446 - loss: 1.0966 - val_accuracy: 0.2294 - val_loss: 1.1046
# Epoch 87/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3464 - loss: 1.0966 - val_accuracy: 0.2345 - val_loss: 1.1050
# Epoch 88/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3377 - loss: 1.0978 - val_accuracy: 0.2062 - val_loss: 1.1065
# Epoch 89/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3533 - loss: 1.0967 - val_accuracy: 0.2062 - val_loss: 1.1078
# Epoch 90/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3529 - loss: 1.0980 - val_accuracy: 0.2320 - val_loss: 1.1044
# Epoch 91/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3568 - loss: 1.0963 - val_accuracy: 0.2371 - val_loss: 1.1030
# Epoch 92/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3703 - loss: 1.0967 - val_accuracy: 0.2500 - val_loss: 1.1011
# Epoch 93/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3620 - loss: 1.0972 - val_accuracy: 0.2680 - val_loss: 1.0999
# Epoch 94/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3368 - loss: 1.0971 - val_accuracy: 0.2680 - val_loss: 1.1011
# Epoch 95/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3542 - loss: 1.0973 - val_accuracy: 0.2629 - val_loss: 1.1008
# Epoch 96/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3564 - loss: 1.0972 - val_accuracy: 0.2758 - val_loss: 1.1000
# Epoch 97/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3455 - loss: 1.0979 - val_accuracy: 0.2680 - val_loss: 1.1005
# Epoch 98/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3368 - loss: 1.0977 - val_accuracy: 0.2500 - val_loss: 1.1029
# Epoch 99/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3577 - loss: 1.0975 - val_accuracy: 0.2629 - val_loss: 1.1021
# Epoch 100/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3611 - loss: 1.0969 - val_accuracy: 0.2552 - val_loss: 1.1032
# Epoch 101/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3520 - loss: 1.0980 - val_accuracy: 0.2242 - val_loss: 1.1031
# Epoch 102/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3590 - loss: 1.0970 - val_accuracy: 0.2242 - val_loss: 1.1033
# Epoch 103/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3498 - loss: 1.0974 - val_accuracy: 0.2062 - val_loss: 1.1049
# Epoch 104/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3520 - loss: 1.0966 - val_accuracy: 0.2268 - val_loss: 1.1042
# Epoch 105/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3568 - loss: 1.0973 - val_accuracy: 0.2603 - val_loss: 1.1021
# Epoch 106/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3685 - loss: 1.0974 - val_accuracy: 0.2526 - val_loss: 1.1017
# Epoch 107/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3542 - loss: 1.0965 - val_accuracy: 0.2345 - val_loss: 1.1043
# Epoch 108/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3538 - loss: 1.0949 - val_accuracy: 0.2474 - val_loss: 1.1050
# Epoch 109/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3546 - loss: 1.0970 - val_accuracy: 0.2758 - val_loss: 1.1007
# Epoch 110/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3464 - loss: 1.0952 - val_accuracy: 0.2809 - val_loss: 1.1000
# Epoch 111/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3516 - loss: 1.0961 - val_accuracy: 0.2655 - val_loss: 1.1011
# Epoch 112/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3533 - loss: 1.0962 - val_accuracy: 0.2629 - val_loss: 1.1044
# Epoch 113/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3611 - loss: 1.0923 - val_accuracy: 0.2268 - val_loss: 1.1036
# Epoch 114/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3555 - loss: 1.0940 - val_accuracy: 0.2758 - val_loss: 1.1009
# Epoch 115/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3625 - loss: 1.0899 - val_accuracy: 0.2680 - val_loss: 1.0999
# Epoch 116/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3677 - loss: 1.0956 - val_accuracy: 0.2629 - val_loss: 1.1016
# Epoch 117/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3642 - loss: 1.0971 - val_accuracy: 0.2526 - val_loss: 1.1020
# Epoch 118/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3512 - loss: 1.0964 - val_accuracy: 0.2552 - val_loss: 1.1009
# Epoch 119/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3698 - loss: 1.0926 - val_accuracy: 0.2732 - val_loss: 1.1005
# Epoch 120/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3694 - loss: 1.0895 - val_accuracy: 0.2423 - val_loss: 1.1036
# Epoch 121/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3520 - loss: 1.0954 - val_accuracy: 0.2861 - val_loss: 1.0997
# Epoch 122/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3681 - loss: 1.0942 - val_accuracy: 0.2629 - val_loss: 1.1026
# Epoch 123/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3551 - loss: 1.0956 - val_accuracy: 0.2294 - val_loss: 1.1043
# Epoch 124/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3751 - loss: 1.0924 - val_accuracy: 0.2655 - val_loss: 1.1017
# Epoch 125/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3672 - loss: 1.0937 - val_accuracy: 0.2629 - val_loss: 1.1024
# Epoch 126/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3629 - loss: 1.0943 - val_accuracy: 0.2474 - val_loss: 1.1043
# Epoch 127/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3698 - loss: 1.0944 - val_accuracy: 0.2887 - val_loss: 1.1025
# Epoch 128/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3751 - loss: 1.0915 - val_accuracy: 0.2706 - val_loss: 1.1017
# Epoch 129/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3733 - loss: 1.0921 - val_accuracy: 0.2887 - val_loss: 1.1011
# Epoch 130/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3477 - loss: 1.0964 - val_accuracy: 0.2835 - val_loss: 1.0993
# Epoch 131/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3616 - loss: 1.0973 - val_accuracy: 0.2603 - val_loss: 1.1005
# Epoch 132/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3620 - loss: 1.0955 - val_accuracy: 0.2887 - val_loss: 1.0990
# Epoch 133/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3664 - loss: 1.0933 - val_accuracy: 0.2732 - val_loss: 1.1002
# Epoch 134/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3698 - loss: 1.0945 - val_accuracy: 0.2964 - val_loss: 1.1009
# Epoch 135/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3703 - loss: 1.0922 - val_accuracy: 0.2964 - val_loss: 1.1031
# Epoch 136/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3620 - loss: 1.0917 - val_accuracy: 0.2706 - val_loss: 1.1023
# Epoch 137/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3690 - loss: 1.0931 - val_accuracy: 0.2577 - val_loss: 1.1028
# Epoch 138/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3664 - loss: 1.0944 - val_accuracy: 0.2680 - val_loss: 1.1034
# Epoch 139/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3751 - loss: 1.0894 - val_accuracy: 0.2861 - val_loss: 1.1016
# Epoch 140/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3785 - loss: 1.0933 - val_accuracy: 0.2732 - val_loss: 1.1059
# Epoch 141/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3672 - loss: 1.0971 - val_accuracy: 0.2861 - val_loss: 1.1036
# Epoch 142/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3525 - loss: 1.0947 - val_accuracy: 0.2732 - val_loss: 1.1011
# Epoch 143/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3564 - loss: 1.0933 - val_accuracy: 0.2680 - val_loss: 1.1030
# Epoch 144/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3803 - loss: 1.0933 - val_accuracy: 0.2732 - val_loss: 1.1044
# Epoch 145/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3755 - loss: 1.0911 - val_accuracy: 0.2577 - val_loss: 1.1042
# Epoch 146/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3585 - loss: 1.0943 - val_accuracy: 0.2629 - val_loss: 1.1030
# Epoch 147/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3646 - loss: 1.0941 - val_accuracy: 0.2655 - val_loss: 1.1026
# Epoch 148/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3733 - loss: 1.0938 - val_accuracy: 0.2577 - val_loss: 1.1041
# Epoch 149/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3655 - loss: 1.0930 - val_accuracy: 0.2655 - val_loss: 1.1027
# Epoch 150/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3577 - loss: 1.0954 - val_accuracy: 0.2552 - val_loss: 1.1033
# Epoch 151/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3659 - loss: 1.0946 - val_accuracy: 0.2732 - val_loss: 1.1021
# Epoch 152/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3711 - loss: 1.0906 - val_accuracy: 0.2809 - val_loss: 1.0997
# Epoch 153/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3625 - loss: 1.0943 - val_accuracy: 0.3067 - val_loss: 1.1015
# Epoch 154/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3677 - loss: 1.0938 - val_accuracy: 0.3119 - val_loss: 1.1007
# Epoch 155/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3820 - loss: 1.0881 - val_accuracy: 0.2655 - val_loss: 1.1052
# Epoch 156/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3585 - loss: 1.0941 - val_accuracy: 0.2500 - val_loss: 1.1035
# Epoch 157/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3811 - loss: 1.0909 - val_accuracy: 0.2603 - val_loss: 1.1013
# Epoch 158/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3598 - loss: 1.0930 - val_accuracy: 0.2345 - val_loss: 1.1024
# Epoch 159/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3685 - loss: 1.0900 - val_accuracy: 0.2320 - val_loss: 1.1050
# Epoch 160/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3711 - loss: 1.0914 - val_accuracy: 0.2371 - val_loss: 1.1027
# Epoch 161/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3777 - loss: 1.0895 - val_accuracy: 0.2732 - val_loss: 1.1015
# Epoch 162/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3738 - loss: 1.0925 - val_accuracy: 0.2887 - val_loss: 1.1029
# Epoch 163/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3829 - loss: 1.0890 - val_accuracy: 0.2706 - val_loss: 1.1035
# Epoch 164/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3751 - loss: 1.0907 - val_accuracy: 0.2758 - val_loss: 1.1025
# Epoch 165/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3620 - loss: 1.0951 - val_accuracy: 0.2758 - val_loss: 1.0997
# Epoch 166/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3716 - loss: 1.0932 - val_accuracy: 0.2784 - val_loss: 1.0994
# Epoch 167/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3768 - loss: 1.0889 - val_accuracy: 0.2809 - val_loss: 1.1008
# Epoch 168/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3672 - loss: 1.0948 - val_accuracy: 0.2887 - val_loss: 1.0977
# Epoch 169/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3751 - loss: 1.0908 - val_accuracy: 0.2809 - val_loss: 1.0985
# Epoch 170/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3759 - loss: 1.0902 - val_accuracy: 0.2990 - val_loss: 1.0963
# Epoch 171/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3720 - loss: 1.0907 - val_accuracy: 0.2887 - val_loss: 1.0990
# Epoch 172/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3681 - loss: 1.0904 - val_accuracy: 0.2784 - val_loss: 1.1006
# Epoch 173/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3720 - loss: 1.0931 - val_accuracy: 0.2861 - val_loss: 1.1006
# Epoch 174/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3781 - loss: 1.0911 - val_accuracy: 0.3015 - val_loss: 1.0984
# Epoch 175/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3768 - loss: 1.0937 - val_accuracy: 0.2912 - val_loss: 1.0988
# Epoch 176/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3859 - loss: 1.0887 - val_accuracy: 0.2887 - val_loss: 1.0969
# Epoch 177/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3694 - loss: 1.0903 - val_accuracy: 0.2835 - val_loss: 1.0971
# Epoch 178/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3738 - loss: 1.0920 - val_accuracy: 0.2861 - val_loss: 1.0993
# Epoch 179/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3716 - loss: 1.0911 - val_accuracy: 0.3247 - val_loss: 1.0974
# Epoch 180/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3690 - loss: 1.0907 - val_accuracy: 0.2835 - val_loss: 1.0995
# Epoch 181/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3781 - loss: 1.0912 - val_accuracy: 0.2887 - val_loss: 1.0982
# Epoch 182/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.3785 - loss: 1.0874 - val_accuracy: 0.2629 - val_loss: 1.0985
# Epoch 183/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3829 - loss: 1.0898 - val_accuracy: 0.2784 - val_loss: 1.0991
# Epoch 184/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3807 - loss: 1.0900 - val_accuracy: 0.2680 - val_loss: 1.0990
# Epoch 185/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3759 - loss: 1.0955 - val_accuracy: 0.2887 - val_loss: 1.0982
# Epoch 186/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3507 - loss: 1.0928 - val_accuracy: 0.3119 - val_loss: 1.0966
# Epoch 187/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3681 - loss: 1.0903 - val_accuracy: 0.2706 - val_loss: 1.1000
# Epoch 188/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3811 - loss: 1.0886 - val_accuracy: 0.2835 - val_loss: 1.0979
# Epoch 189/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3933 - loss: 1.0843 - val_accuracy: 0.3067 - val_loss: 1.0960
# Epoch 190/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3659 - loss: 1.0922 - val_accuracy: 0.2964 - val_loss: 1.0977
# Epoch 191/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3698 - loss: 1.0931 - val_accuracy: 0.3505 - val_loss: 1.0962
# Epoch 192/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3672 - loss: 1.0936 - val_accuracy: 0.3402 - val_loss: 1.0973
# Epoch 193/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3777 - loss: 1.0906 - val_accuracy: 0.2964 - val_loss: 1.0971
# Epoch 194/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3772 - loss: 1.0855 - val_accuracy: 0.2784 - val_loss: 1.0988
# Epoch 195/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3685 - loss: 1.0869 - val_accuracy: 0.2964 - val_loss: 1.0972
# Epoch 196/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3764 - loss: 1.0887 - val_accuracy: 0.3247 - val_loss: 1.0968
# Epoch 197/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3685 - loss: 1.0879 - val_accuracy: 0.3351 - val_loss: 1.0982
# Epoch 198/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3720 - loss: 1.0910 - val_accuracy: 0.3093 - val_loss: 1.1001
# Epoch 199/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3933 - loss: 1.0859 - val_accuracy: 0.2706 - val_loss: 1.1026
# Epoch 200/200
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3868 - loss: 1.0874 - val_accuracy: 0.2680 - val_loss: 1.1021

# %% [markdown]
# ### **Model Evaluation**

# %%
y_pred=model.predict(X_test_preprocessed)
y_pred
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# array([[0.30407152, 0.30652857, 0.38939992],
#        [0.30406973, 0.30652714, 0.38940316],
#        [0.3480261 , 0.34863323, 0.30334067],
#        ...,
#        [0.30964372, 0.31095842, 0.37939787],
#        [0.31329837, 0.31489405, 0.37180758],
#        [0.30894428, 0.31040484, 0.38065088]],
#       shape=(388, 3), dtype=float32)

# %%
y_pred= np.argmax(y_pred, axis=1)

##accuracy,precision,recall,f1 score for test data
accuracy_test = accuracy_score(y_pred,Y_test)
precision_test = precision_score(y_pred,Y_test,average="weighted")
recall_test = recall_score(y_pred,Y_test,average="weighted")
f1_test = f1_score(y_pred,Y_test,average="weighted")

##print accuracy,precision,recall,f1 score
print(f"Accuracy of the ANN model:{accuracy_test}")
print(f"Precision of the ANN model:{precision_test}")
print(f"Recall of the ANN model:{recall_test}")
print(f"F1 Score of the ANN model:{f1_test}")
# Out:
# Accuracy of the ANN model:0.26804123711340205
# Precision of the ANN model:0.4508177964020465
# Recall of the ANN model:0.26804123711340205
# F1 Score of the ANN model:0.28324778704423625

# %%
y_pred_train=model.predict(X_train_resample)
y_pred_train= np.argmax(y_pred_train, axis=1)

##accuracy,precision,recall,f1 score for training data
accuracy_train = accuracy_score(y_pred_train,Y_train_resample)
precision_train = precision_score(y_pred_train,Y_train_resample,average="weighted")
recall_train = recall_score(y_pred_train,Y_train_resample,average="weighted")
f1_train = f1_score(y_pred_train,Y_train_resample,average="weighted")

print(f"Accuracy of the ANN model:{accuracy_train}")
print(f"Precision of the ANN model:{precision_train}")
print(f"Recall of the ANN model:{recall_train}")
print(f"F1 Score of the ANN model:{f1_train}")
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy of the ANN model:0.4228596262494568
# Precision of the ANN model:0.5633438667049698
# Recall of the ANN model:0.4228596262494568
# F1 Score of the ANN model:0.4568485500742887

# %%
##print classification report
print("Classification Report:")
print(classification_report(Y_test,y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.41      0.14      0.20       192
#            1       0.34      0.28      0.30       127
#            2       0.19      0.62      0.30        69
#
#     accuracy                           0.27       388
#    macro avg       0.31      0.34      0.27       388
# weighted avg       0.35      0.27      0.25       388
